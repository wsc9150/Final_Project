# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 필요없는단어 지우기

# %%
df = pd.read_excel('C:/Users/82108/jupyter notebook/multicampus.final.project/mbti_book_revised.xlsx')

# %%
df.head(1)
# Out:
#           title                                             author publisher  \
# 0  트렌드 코리아 2020  김난도, 전미영, 최지혜, 이향은, 이준영, 김서영, 이수진, 서유현, 권정윤 (지...      미래의창
#
#             isbn                                     keyword  \
# 0  9790000000000  ['경제전망', '소비자', '페르소나', '소비', '마우스', '밀레']
#
#                                                image
# 0  https://image.aladin.co.kr/product/21094/63/co...

# %%
# 단어 리스트 만들기
def make_list(df) :
    keyword_list = []
    for i in range(len(df)):
        temp = []
        
        for j in range(len(df['keyword'][i].split('\''))):
            if j % 2 == 1:
                temp.append(df['keyword'][i].split('\'')[j])
        keyword_list.append(temp)
    
    return keyword_list

# %%
keyword_list=make_list(df)

# %%
keyword_list
# Out:
# [['경제전망', '소비자', '페르소나', '소비', '마우스', '밀레'],
#  ['자기관리', '크리에이터', '인공지능', '사업 모델', '톱니바퀴', '예술가'],
#  ['부자되는법', '재테크', '스크립트', '머니', '돈 관리', '백만장자'],
#  ['부자되는법', '부자', '성공법', '백만장자', '퇴직 연금', '구루'],
#  ['심리학자', '리더십', '조직관리', '스타트업', '월스트리트 저널', '게이츠'],
#  ['부자되는법', '무형 자산', '방정식', '부의법칙', '유형 자산', '연결'],
#  ['재테크', '일반 투자자', '수익', '애널리스트', '시장 분석', '회계'],
#  ['부자되는법', '부자', '경제', '성공', '부의법칙', '마인드'],
#  ['부자되는법', '분산 투자', '경제학자', '부의법칙', '우석', '천재'],
#  ['금융 시장', '매일', '트레이딩', '기쁨', '슬픔', '왕관'],
#  ['재무제표', '회계지식', '파산', '국제회계기준', '자산', '분식'],
#  ['행동 경제학', '캠페인', '시민단체', '타성', '범죄 예방'],
#  ['초보투자자', '가치 투자', '거래량', '개미', '시장 환경', '조언'],
#  ['부동산투자', '투자', '시장', '부동산시장', '정책', '거래량'],
#  ['주식', '투자', '주식투자', '문맹', '투자방법', '빈곤'],
#  ['부자되는법', '재테크', '금융', '부동산', '복지 정책', '세금'],
#  ['불안', '강연', '패스워드', '포즈', '이타주의', '인공지능 시대'],
#  ['꼰대', '밀레니얼세대', '신입 사원', '소비자', '20대', '기업'],
#  ['가치 투자', '주식 시장', '주식투자', '펀드 매니저', '주식투자기법', '투자철학'],
# ...

# %%
word= pd.read_excel('C:/Users/82108/jupyter notebook/multicampus.final.project/keyword_freq.xlsx')

# %%
word
# Out:
#             key  count  mbti-S         mbti-W
# 0            자신   1035      16            NaN
# 1            생각    813       8            NaN
# 2            역사    423     2,8            NaN
# 3            사회    328       2            NaN
# 4            감정    318    3,11  7,11,13,15,16
# ...         ...    ...     ...            ...
# 2333    판타지과학대전      1       7            NaN
# 2334    판타지수학대전      1       7            NaN
# 2335  백만장자에도전하기      1       9            NaN
# 2336  한국은행경제이야기      1  5,8,13            NaN
# 2337       긍정의힘      1     3,7            NaN
#
# [2338 rows x 4 columns]

# %% [markdown]
# ### test

# %%
test1=set(keyword_list[0])
test1
# Out:
# {'경제전망', '마우스', '밀레', '소비', '소비자', '페르소나'}

# %%
len(test2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2d47c0b5e1cd> in <module>
# ----> 1 len(test2)
#
# NameError: name 'test2' is not defined

# %% [markdown]
# ## 교집합 단어 찾기

# %%
keyword_final=[]
test2=set(word['key'])

for i in range(len(keyword_list)):
    test1=set(keyword_list[i])
    check=list(test1.intersection(test2))
    keyword_final.append(check)

# %%
len(keyword_final)
# Out:
# 7638

# %%
df['keyword_final']=keyword_final

# %%
df.head()
# Out:
#                title                                             author  \
# 0       트렌드 코리아 2020  김난도, 전미영, 최지혜, 이향은, 이준영, 김서영, 이수진, 서유현, 권정윤 (지...
# 1                린치핀                            세스 고딘 (지은이), 윤영삼 (옮긴이)
# 2  부자 되는 법을 가르쳐 드립니다                            라밋 세티 (지은이), 김태훈 (옮긴이)
# 3            부의 추월차선                          엠제이 드마코 (지은이), 신소영 (옮긴이)
# 4             리더의 용기                          브레네 브라운 (지은이), 강주헌 (옮긴이)
#
#   publisher           isbn                                            keyword  \
# 0      미래의창  9790000000000         ['경제전망', '소비자', '페르소나', '소비', '마우스', '밀레']
# 1    라이스메이커  9790000000000  ['자기관리', '크리에이터', '인공지능', '사업 모델', '톱니바퀴', '예술가']
# 2    안드로메디안  9790000000000     ['부자되는법', '재테크', '스크립트', '머니', '돈 관리', '백만장자']
# 3        토트  9790000000000      ['부자되는법', '부자', '성공법', '백만장자', '퇴직 연금', '구루']
# 4       갤리온  9790000000000  ['심리학자', '리더십', '조직관리', '스타트업', '월스트리트 저널', '게...
#
# ...

# %%
len(df['keyword_final'][2])
# Out:
# 0

# %%
# 데이터 생성

df.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/df.xlsx',encoding='utf-8-sig',index=False)

# %%
df['keyword_final']
# Out:
# 0                                              [경제전망]
# 1                                        [예술가, 사업 모델]
# 2                                                  []
# 3                                                  []
# 4                                   [리더십, 심리학자, 조직관리]
#                             ...
# 7633    [습관, 생각, 원칙, 결정, 상상력, 정확, 자아정체성, 독립, 호기심, 자신]
# 7634                                          [기초 수학]
# 7635                                               []
# 7636                                               []
# 7637                        [습관, 자존감, 자존감수업, 실용적, 용기]
# Name: keyword_final, Length: 7638, dtype: object

# %%
df.head()
# Out:
#                title                                             author  \
# 0       트렌드 코리아 2020  김난도, 전미영, 최지혜, 이향은, 이준영, 김서영, 이수진, 서유현, 권정윤 (지...
# 1                린치핀                            세스 고딘 (지은이), 윤영삼 (옮긴이)
# 2  부자 되는 법을 가르쳐 드립니다                            라밋 세티 (지은이), 김태훈 (옮긴이)
# 3            부의 추월차선                          엠제이 드마코 (지은이), 신소영 (옮긴이)
# 4             리더의 용기                          브레네 브라운 (지은이), 강주헌 (옮긴이)
#
#   publisher           isbn                                            keyword  \
# 0      미래의창  9790000000000         ['경제전망', '소비자', '페르소나', '소비', '마우스', '밀레']
# 1    라이스메이커  9790000000000  ['자기관리', '크리에이터', '인공지능', '사업 모델', '톱니바퀴', '예술가']
# 2    안드로메디안  9790000000000     ['부자되는법', '재테크', '스크립트', '머니', '돈 관리', '백만장자']
# 3        토트  9790000000000      ['부자되는법', '부자', '성공법', '백만장자', '퇴직 연금', '구루']
# 4       갤리온  9790000000000  ['심리학자', '리더십', '조직관리', '스타트업', '월스트리트 저널', '게...
#
# ...

# %%
#final=pd.DataFrame(columns=['title','author','publisher','isbn','image','keyword_final'])
id=[]


for idx in range(len(df)):
    if len(df['keyword_final'][idx])>0:
        id.append(idx)
       ##key_list.append(df['keyword_final'][idx])
        
df=df.iloc[id,:]

# %%
df.head(5)
# Out:
#                     title                                             author  \
# 0            트렌드 코리아 2020  김난도, 전미영, 최지혜, 이향은, 이준영, 김서영, 이수진, 서유현, 권정윤 (지...
# 1                     린치핀                            세스 고딘 (지은이), 윤영삼 (옮긴이)
# 4                  리더의 용기                          브레네 브라운 (지은이), 강주헌 (옮긴이)
# 6  재무제표 모르면 주식투자 절대로 하지마라                                          사경인 (지은이)
# 7                백만장자 시크릿                            하브 에커 (지은이), 나선숙 (옮긴이)
#
#       publisher           isbn  \
# 0          미래의창  9790000000000
# 1        라이스메이커  9790000000000
# 4           갤리온  9790000000000
# 6          베가북스  9790000000000
# 7  알에이치코리아(RHK)  9790000000000
#
#                                              keyword  \
# 0         ['경제전망', '소비자', '페르소나', '소비', '마우스', '밀레']
# 1  ['자기관리', '크리에이터', '인공지능', '사업 모델', '톱니바퀴', '예술가']
# 4  ['심리학자', '리더십', '조직관리', '스타트업', '월스트리트 저널', '게...
# 6    ['재테크', '일반 투자자', '수익', '애널리스트', '시장 분석', '회계']
# ...

# %%
# 인덱스 정리
#df.reset_index(drop=True,inplace=True)

# %%
df.head(2)
# Out:
#           title                                             author publisher  \
# 0  트렌드 코리아 2020  김난도, 전미영, 최지혜, 이향은, 이준영, 김서영, 이수진, 서유현, 권정윤 (지...      미래의창
# 1           린치핀                            세스 고딘 (지은이), 윤영삼 (옮긴이)     라이스메이커
#
#             isbn                                            keyword  \
# 0  9790000000000         ['경제전망', '소비자', '페르소나', '소비', '마우스', '밀레']
# 1  9790000000000  ['자기관리', '크리에이터', '인공지능', '사업 모델', '톱니바퀴', '예술가']
#
#                                                image keyword_final
# 0  https://image.aladin.co.kr/product/21094/63/co...        [경제전망]
# 1  https://image.aladin.co.kr/product/22213/37/co...  [예술가, 사업 모델]

# %%
keyword_final=df['keyword_final']

# %% [markdown]
# # 군집분석

# %% [markdown]
# ### Word2vec

# %%
from gensim.models.word2vec import Word2Vec

# %%
embedding_model = Word2Vec(keyword_final, size=100, window = 2, min_count=2, workers=5, iter=1000, sg=1, sample=1e-3)

# %% [markdown]
# - 벡터화된 단어들로 KMeans Clustering

# %%
from sklearn.cluster import KMeans

word_vectors = embedding_model.wv.syn0 # 어휘의 feature vector
# num_clusters = int(word_vectors.shape[0]/500) # 어휘 크기의 1/5나 평균 5단어
# print(num_clusters)
# num_clusters = int(num_clusters)

# %%
word_vectors
# Out:
# array([[-0.36325765,  0.17310645, -0.60679924, ..., -0.5503597 ,
#         -0.4560755 ,  0.5912865 ],
#        [-0.31411928,  0.02494944,  0.33213943, ..., -0.85303897,
#         -0.44758266,  0.77525777],
#        [ 0.3268582 ,  0.4475279 , -0.37333614, ...,  0.7245616 ,
#          0.51539034,  0.25582224],
#        ...,
#        [ 0.29128057,  0.42343375, -0.7553843 , ...,  0.1284819 ,
#         -0.08913117,  0.49660346],
#        [ 0.12544526,  0.03397031, -0.3008227 , ..., -0.60416085,
#          0.16772604,  1.1144547 ],
#        [-0.7227316 ,  0.12751597,  0.66816723, ..., -0.37759352,
#         -0.0765017 ,  0.48645976]], dtype=float32)

# %% [markdown]
# ### 16개 군집

# %%
kmeans_clustering = KMeans(n_clusters=50)
idx = kmeans_clustering.fit_predict(word_vectors)

idx = list(idx)
names = embedding_model.wv.index2word
word_centroid_map = {names[i]: idx[i] for i in range(len(names))}

# %%
for c in range(50):
    # 클러스터 번호를 출력
    print("\ncluster {}".format(c))
    
    words = []
    cluster_values = list(word_centroid_map.values())
    for i in range(len(cluster_values)):
        if (cluster_values[i] == c):
            words.append(list(word_centroid_map.keys())[i])            
    print(words)
# Out:
# cluster 0
# ['정신 분석', '인지발달이론', '정신 분석 이론']
#
# cluster 1
# ['세계탐험만화역사상식', '신화', '한국사탐험만화역사상식', '교통', '세계사탐험만화역사상식', '교류', '세계도시탐험역사상식', '세계도시탐험만화역사상식', '지배자']
#
# cluster 2
# ['음악 이론', '개인 사업자', '스릴러 작가', '블랙 유머', '과학 혁명', '의사소통 장애', '미스터리 작가', '양자 이론', '상권 분석', '기초 이론', '연속함수', '분석법', '보건 의료', '문화 이론', '전업 작가', '과학소설', '디지털경제', '회계 원리', '경쟁 전략', '프로그래밍 언어', '중재', '정치 경제학', '개인 정보', '페미니즘문학', '이상향', '병법', '언어 문화', '프랑스철학', '성공 철학', '사업 계획서', '업무기술', '과학교양서', '디지털 논리 회로', '간호학', '정신과학', '기초 수학', '한국정치사', '갈등 이론', '발달 이론', '목표 설정', '북한정치', '부끄러움', '실천 문학', '편협', '색채이론', '시나리오 작가', '피아노이론', '의료 기술', '역사기행', '일본추리소설', '로맨스 판타지', '집중듣기']
#
# cluster 3
# ['주식', '분석', '전략', '권리분석', '사업', '주식시장', '주식펀드', '대책', '차트분석', '회계사', '장기투자', '우리가정말알아야할통계상식백가지', '난생처음주식투자', '주식 펀드']
#
# cluster 4
# ...

# %%
words = [[] for _ in range(50)]

for c in range(50):
    # 클러스터 번호를 출력
    print("\ncluster {}".format(c))
    
    cluster_values = list(word_centroid_map.values())
    for i in range(len(cluster_values)):
        if (cluster_values[i] == c):
            words[c].append(list(word_centroid_map.keys())[i])
# Out:
# cluster 0
#
# cluster 1
#
# cluster 2
#
# cluster 3
#
# cluster 4
#
# cluster 5
#
# cluster 6
#
# cluster 7
#
# cluster 8
#
# cluster 9
#
# cluster 10
#
# cluster 11
#
# cluster 12
#
# cluster 13
#
# cluster 14
#
# cluster 15
#
# cluster 16
#
# cluster 17
#
# cluster 18
#
# cluster 19
#
# cluster 20
#
# cluster 21
#
# cluster 22
#
# cluster 23
#
# cluster 24
#
# cluster 25
#
# cluster 26
#
# cluster 27
#
# cluster 28
#
# cluster 29
#
# cluster 30
#
# cluster 31
#
# cluster 32
#
# cluster 33
#
# cluster 34
#
# cluster 35
#
# cluster 36
#
# cluster 37
#
# cluster 38
#
# cluster 39
#
# cluster 40
#
# cluster 41
#
# cluster 42
#
# cluster 43
#
# cluster 44
#
# cluster 45
#
# cluster 46
#
# cluster 47
#
# cluster 48
#
# cluster 49

# %%
cluster = pd.DataFrame(words)

# %%
cluster.head()
# Out:
#            0       1            2      3            4        5           6   \
# 0       정신 분석  인지발달이론     정신 분석 이론   None         None     None        None
# 1  세계탐험만화역사상식      신화  한국사탐험만화역사상식     교통  세계사탐험만화역사상식       교류  세계도시탐험역사상식
# 2       음악 이론  개인 사업자       스릴러 작가  블랙 유머        과학 혁명  의사소통 장애     미스터리 작가
# 3          주식      분석           전략   권리분석           사업     주식시장        주식펀드
# 4          자신      공감           용기     현실           웃음       법칙          걱정
#
#              7      8      9   ...     47    48      49       50    51    52  \
# 0          None   None   None  ...   None  None    None     None  None  None
# 1  세계도시탐험만화역사상식    지배자   None  ...   None  None    None     None  None  None
# 2         양자 이론  상권 분석  기초 이론  ...  의료 기술  역사기행  일본추리소설  로맨스 판타지  집중듣기  None
# 3            대책   차트분석    회계사  ...   None  None    None     None  None  None
# 4            도전     섬세     배려  ...   None  None    None     None  None  None
#
#      53    54    55    56
# ...

# %%
cluster.T
# Out:
#           0             1          2                 3       4     5   \
# 0      정신 분석    세계탐험만화역사상식      음악 이론                주식      자신    결정
# 1     인지발달이론            신화     개인 사업자                분석      공감  None
# 2   정신 분석 이론   한국사탐험만화역사상식     스릴러 작가                전략      용기  None
# 3       None            교통      블랙 유머              권리분석      현실  None
# 4       None   세계사탐험만화역사상식      과학 혁명                사업      웃음  None
# 5       None            교류    의사소통 장애              주식시장      법칙  None
# 6       None    세계도시탐험역사상식    미스터리 작가              주식펀드      걱정  None
# 7       None  세계도시탐험만화역사상식      양자 이론                대책      도전  None
# 8       None           지배자      상권 분석              차트분석      섬세  None
# 9       None          None      기초 이론               회계사      배려  None
# 10      None          None       연속함수              장기투자      집중  None
# 11      None          None        분석법  우리가정말알아야할통계상식백가지      계획  None
# ...

# %%
# 데이터 저장
cluster.to_xlsx('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster.xlsx',encoding='utf-8-sig',index='False')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-491c61baf857> in <module>
#       1 # 데이터 저장
# ----> 2 cluster.to_xlsx('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster.xlsx',encoding='utf-8-sig',index='False')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_xlsx'

# %%
words[0]
# Out:
# ['작가']

# %%
cluster_1 = pd.DataFrame(words[0])

# %%
cluster_2 = pd.DataFrame(words[1])
# Out:
#          0
# 0      리더십
# 1     경영전략
# 2       혁신
# 3    마케팅전략
# 4       설득
# 5     조직관리
# 6   마케팅 전략
# 7     경영혁신
# 8      정치인
# 9    사업 모델
# 10   목표 달성
# 11      전술
# 12  비즈니스전략
# 13  온라인마케팅
# 14   기술 혁신
# 15     신사업
# 16    위기관리
# 17   브랜드전략
# 18   갈등 관리
# 19   정책 결정

# %%
cluster_3 = pd.DataFrame(words[2])

# %%
cluster_4 = pd.DataFrame(words[3])

# %%
cluster_5 = pd.DataFrame(words[4])

# %%
cluster_6 = pd.DataFrame(words[5])

# %%
cluster_7 = pd.DataFrame(words[6])

# %%
cluster_8 = pd.DataFrame(words[7])

# %%
cluster_9 = pd.DataFrame(words[8])

# %%
cluster_10 = pd.DataFrame(words[9])

# %%
cluster_11 = pd.DataFrame(words[10])

# %%
cluster_12 = pd.DataFrame(words[11])

# %%
cluster_13 = pd.DataFrame(words[12])

# %%
cluster_14 = pd.DataFrame(words[13])

# %%
cluster_15 = pd.DataFrame(words[14])

# %%
cluster_16 = pd.DataFrame(words[15])

# %%
cluster_17 = pd.DataFrame(words[16])

# %%
cluster_18 = pd.DataFrame(words[17])

# %%
cluster_19 = pd.DataFrame(words[18])

# %%
cluster_20 = pd.DataFrame(words[19])

# %%
cluster_21 = pd.DataFrame(words[20])

# %%
cluster_22 = pd.DataFrame(words[21])

# %%
cluster_23 = pd.DataFrame(words[22])

# %%
cluster_24 = pd.DataFrame(words[24])

# %%
cluster_25 = pd.DataFrame(words[26])

# %%
cluster_27 = pd.DataFrame(words[28])

# %%
cluster_29 = pd.DataFrame(words[29])

# %%
cluster_30 = pd.DataFrame(words[29])

# %%
cluster_31 = pd.DataFrame(words[30])

# %%
cluster_32 = pd.DataFrame(words[31])

# %%
cluster_33 = pd.DataFrame(words[32])

# %%
cluster_34 = pd.DataFrame(words[33])

# %%
cluster_35 = pd.DataFrame(words[34])

# %%
cluster_36 = pd.DataFrame(words[35])

# %%
cluster_37 = pd.DataFrame(words[36])

# %%
cluster_38 = pd.DataFrame(words[37])

# %%
cluster_39 = pd.DataFrame(words[38])

# %%
cluster_40 = pd.DataFrame(words[39])

# %%
cluster_41 = pd.DataFrame(words[40])

# %%
cluster_42 = pd.DataFrame(words[41])

# %%
cluster_43 = pd.DataFrame(words[42])

# %%
cluster_44 = pd.DataFrame(words[43])

# %%
cluster_45 = pd.DataFrame(words[44])

# %%
cluster_46 = pd.DataFrame(words[45])

# %%
cluster_47 = pd.DataFrame(words[46])

# %%
cluster_48 = pd.DataFrame(words[47])

# %%
cluster_49 = pd.DataFrame(words[48])

# %%
cluster_50 = pd.DataFrame(words[49])

# %% [markdown]
# ### 데이터 저장하기

# %%
# 데이터 저장
cluster_1.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster.csv',encoding='utf-8-sig',index='False')

# %%
cluster_2.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %%
cluster_3.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster3.csv',encoding='utf-8-sig',index='False')

# %%
cluster_4.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster4.csv',encoding='utf-8-sig',index='False')

# %%
cluster_5.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster5.csv',encoding='utf-8-sig',index='False')

# %%
cluster_6.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster6.csv',encoding='utf-8-sig',index='False')

# %%
cluster_7.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster7.csv',encoding='utf-8-sig',index='False')

# %%
cluster_8.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster8.csv',encoding='utf-8-sig',index='False')

# %%
cluster_9.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster9.csv',encoding='utf-8-sig',index='False')

# %%
cluster_10.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster10.csv',encoding='utf-8-sig',index='False')

# %%
cluster_11.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster11.csv',encoding='utf-8-sig',index='False')

# %%
cluster_12.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster12.csv',encoding='utf-8-sig',index='False')

# %%
cluster_13.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster13.csv',encoding='utf-8-sig',index='False')

# %%
cluster_14.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster14.csv',encoding='utf-8-sig',index='False')

# %%
cluster_15.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster15.csv',encoding='utf-8-sig',index='False')

# %%
cluster_16.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster16.csv',encoding='utf-8-sig',index='False')

# %%
cluster_17.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster17.csv',encoding='utf-8-sig',index='False')

# %%
cluster_18.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster18.csv',encoding='utf-8-sig',index='False')

# %%
cluster_19.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster19.csv',encoding='utf-8-sig',index='False')

# %%
cluster_20.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster20.csv',encoding='utf-8-sig',index='False')

# %%
cluster_21.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster21.csv',encoding='utf-8-sig',index='False')

# %%
cluster_22.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster22.csv',encoding='utf-8-sig',index='False')

# %%
cluster_23.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster23.csv',encoding='utf-8-sig',index='False')

# %%
cluster_24.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster24.csv',encoding='utf-8-sig',index='False')

# %%
cluster_25.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster25.csv',encoding='utf-8-sig',index='False')

# %%
cluster_26.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster26.csv',encoding='utf-8-sig',index='False')

# %%
cluster_27.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster27.csv',encoding='utf-8-sig',index='False')

# %%
cluster_28.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster28.csv',encoding='utf-8-sig',index='False')

# %%
cluster_29.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster29.csv',encoding='utf-8-sig',index='False')

# %%
cluster_30.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster30.csv',encoding='utf-8-sig',index='False')

# %%
cluster_31.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster31.csv',encoding='utf-8-sig',index='False')

# %%
cluster_32.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster32.csv',encoding='utf-8-sig',index='False')

# %%
cluster_33.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster33.csv',encoding='utf-8-sig',index='False')

# %%
cluster_34.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster34.csv',encoding='utf-8-sig',index='False')

# %%
cluster_35.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster35.csv',encoding='utf-8-sig',index='False')

# %%
cluster_36.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster36.csv',encoding='utf-8-sig',index='False')

# %%
cluster_37.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster37.csv',encoding='utf-8-sig',index='False')

# %%
cluster_38.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster38.csv',encoding='utf-8-sig',index='False')

# %%
cluster_39.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster39.csv',encoding='utf-8-sig',index='False')

# %%
cluster_40.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster40.csv',encoding='utf-8-sig',index='False')

# %%
cluster_41.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %%
cluster_42.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %%
cluster_43.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %%
cluster_44.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %%
cluster_45.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %%
cluster_46.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %%
cluster_47.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %%
cluster_48.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %%
cluster_49.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %%
cluster_50.to_csv('C:/Users/82108/jupyter notebook/multicampus.final.project/cluster2.csv',encoding='utf-8-sig',index='False')

# %% [markdown]
# ### MBTI

# %%
kmeans_clustering = KMeans(n_clusters=16)
idx = kmeans_clustering.fit_predict(word_vectors)

idx = list(idx)
names = embedding_model.wv.index2word
word_centroid_map = {names[i]: idx[i] for i in range(len(names))}

# %%
words = [[] for _ in range(16)]

for c in range(16):
    # 클러스터 번호를 출력
    print("\ncluster {}".format(c))
    
    cluster_values = list(word_centroid_map.values())
    for i in range(len(cluster_values)):
        if (cluster_values[i] == c):
            words[c].append(list(word_centroid_map.keys())[i])            
    # print(words)
# Out:
# cluster 0
#
# cluster 1
#
# cluster 2
#
# cluster 3
#
# cluster 4
#
# cluster 5
#
# cluster 6
#
# cluster 7
#
# cluster 8
#
# cluster 9
#
# cluster 10
#
# cluster 11
#
# cluster 12
#
# cluster 13
#
# cluster 14
#
# cluster 15

# %%
mbti_cluster_1 = pd.DataFrame(words[0])

# %%
mbti_cluster_1
# Out:
#         0
# 0    주식투자
# 1     재테크
# 2    인공지능
# 3      투자
# 4     투자자
# ..    ...
# 677    하락
# 678    정석
# 679   자양동
# 680    학파
# 681    학군
#
# [682 rows x 1 columns]

# %%
mbti_cluster_1.to_csv('./data/final/mbti_cluster_1.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_2 = pd.DataFrame(words[1])

# %%
mbti_cluster_2.to_csv('./data/final/mbti_cluster_2.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_3 = pd.DataFrame(words[2])

# %%
mbti_cluster_3.to_csv('./data/final/mbti_cluster_3.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_4 = pd.DataFrame(words[3])

# %%
mbti_cluster_4.to_csv('./data/final/mbti_cluster_4.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_5 = pd.DataFrame(words[4])

# %%
mbti_cluster_5.to_csv('./data/final/mbti_cluster_5.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_6 = pd.DataFrame(words[5])

# %%
mbti_cluster_6.to_csv('./data/final/mbti_cluster_6.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_7 = pd.DataFrame(words[6])

# %%
mbti_cluster_7.to_csv('./data/final/mbti_cluster_7.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_8 = pd.DataFrame(words[7])

# %%
mbti_cluster_8.to_csv('./data/final/mbti_cluster_8.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_9 = pd.DataFrame(words[8])

# %%
mbti_cluster_9.to_csv('./data/final/mbti_cluster_9.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_10 = pd.DataFrame(words[9])

# %%
mbti_cluster_10.to_csv('./data/final/mbti_cluster_10.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_11 = pd.DataFrame(words[10])

# %%
mbti_cluster_11.to_csv('./data/final/mbti_cluster_11.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_12 = pd.DataFrame(words[11])

# %%
mbti_cluster_12.to_csv('./data/final/mbti_cluster_12.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_13 = pd.DataFrame(words[12])

# %%
mbti_cluster_13.to_csv('./data/final/mbti_cluster_13.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_14 = pd.DataFrame(words[13])

# %%
mbti_cluster_14.to_csv('./data/final/mbti_cluster_14.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_15 = pd.DataFrame(words[14])

# %%
mbti_cluster_15.to_csv('./data/final/mbti_cluster_15.csv',encoding='utf-8-sig',index='False')

# %%
mbti_cluster_16 = pd.DataFrame(words[15])

# %%
mbti_cluster_16.to_csv('./data/final/mbti_cluster_16.csv',encoding='utf-8-sig',index='False')
